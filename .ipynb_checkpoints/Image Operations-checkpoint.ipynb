# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

# %% [markdown]
# # Image Segmentation?

# %%
xray = plt.imread('data/cara-shelton-_GpJpHnyCSw-unsplash.jpg')
plt.imshow(xray)
plt.show()
